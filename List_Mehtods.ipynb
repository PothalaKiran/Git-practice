# %% [markdown]
# <a href="https://colab.research.google.com/github/PothalaKiran/Git-practice/blob/main/List_Mehtods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# List Methods

# %%
#Append method -->To add the values in the end of the list
fruits = ['apple','banana','cherry']
print(fruits)
fruits.append('orange')
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'orange']
