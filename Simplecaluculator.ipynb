# %% [markdown]
# <a href="https://colab.research.google.com/github/PothalaKiran/Git-practice/blob/main/Simplecaluculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Calculator application

a= int (input("Enter first number: "))
b= int (input("Enter second number: "))
operation=input("Enter the operation: +,-,*,/ ")

if operation == "+":
    print("The additon of two values is :",a+b)
if operation == "-":
    print("The subtraction of two values is :",a-b)
if operation == "*":
    print("The multiplication of two values is :",a*b)
if operation =="/":
  print("The division of two values is :",a/b)
# Out:
# Enter first number: 96
# Enter second number: 69
# Enter the operation: +,-,*,/ -
# The subtraction of two values is : 27
